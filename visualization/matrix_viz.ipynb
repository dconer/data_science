# %% [markdown]
# ## Index
# 1. imgshow for mapping a matrix to color
# 2. imread to store a image in a matrix form
# 3. heatmap diagram with seaborn

# %% [markdown]
# ### 1. imgshow for mapping a matrix to color

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Initialize columns and rows
m = 3
n = 5
M = np.random.randint(10,size=(m,n))
print(M)

# Mapping the matrix into color
plt.imshow(M)

# Write down the coefficients of the matrix into the color matrix
for i in range(m):
    for j in range(n):
        plt.text(j,i,str(M[i,j]),horizontalalignment='center',fontsize=28, verticalalignment='center')
        
# Add a colorbar
plt.colorbar()
plt.show()
# Out:
# [[3 2 8 5 8]
#  [3 9 9 6 5]
#  [8 1 9 1 9]]

# %% [markdown]
# ### 2. imread to store a image in a matrix form

# %%
from imageio import imread 

# To store a image in a matrix form in img
img = imread('https://upload.wikimedia.org/wikipedia/en/8/86/Einstein_tongue.jpg')

# Show image
plt.imshow(img)
# Out:
# /tmp/ipykernel_1015/244715552.py:4: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imread('https://upload.wikimedia.org/wikipedia/en/8/86/Einstein_tongue.jpg')
# Array([[59, 60, 62, ..., 62, 60, 48],
#        [61, 62, 64, ..., 61, 56, 47],
#        [61, 63, 64, ..., 56, 51, 47],
#        ...,
#        [45, 48, 43, ..., 37, 50, 34],
#        [36, 50, 44, ..., 29, 40, 22],
#        [29, 48, 43, ..., 19, 50, 45]], dtype=uint8)

# %%
res = plt.hist(img.ravel(),bins=100)

# %%
plt.imshow(255-img, cmap = 'Greys',vmin=150,vmax=250) #cmap: color map
plt.xticks([])
plt.yticks([])
plt.colorbar()
plt.show()

# %% [markdown]
# ### 3. heatmap diagram with seaborn

# %%
from IPython import display 
display.set_matplotlib_formats('svg')
# Out:
# /tmp/ipykernel_1015/2328224503.py:2: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   display.set_matplotlib_formats('svg')

# %%
import seaborn as sns
# Initialize variables
size = 10
hilb_mat = np.zeros((size,size))
# Create Hilbert matrix
for i in range(size):
    for j in range(size):
        hilb_mat[i,j] = 1/(i+j+1)
# Visualize matrix
sns.heatmap(hilb_mat,cmap="Blues", vmax=0.1)
plt.savefig('heatmap.pdf')
plt.show()
hilb_mat
# Out:
# array([[1.        , 0.5       , 0.33333333, 0.25      , 0.2       ,
#         0.16666667, 0.14285714, 0.125     , 0.11111111, 0.1       ],
#        [0.5       , 0.33333333, 0.25      , 0.2       , 0.16666667,
#         0.14285714, 0.125     , 0.11111111, 0.1       , 0.09090909],
#        [0.33333333, 0.25      , 0.2       , 0.16666667, 0.14285714,
#         0.125     , 0.11111111, 0.1       , 0.09090909, 0.08333333],
#        [0.25      , 0.2       , 0.16666667, 0.14285714, 0.125     ,
#         0.11111111, 0.1       , 0.09090909, 0.08333333, 0.07692308],
#        [0.2       , 0.16666667, 0.14285714, 0.125     , 0.11111111,
#         0.1       , 0.09090909, 0.08333333, 0.07692308, 0.07142857],
#        [0.16666667, 0.14285714, 0.125     , 0.11111111, 0.1       ,
#         0.09090909, 0.08333333, 0.07692308, 0.07142857, 0.06666667],
#        [0.14285714, 0.125     , 0.11111111, 0.1       , 0.09090909,
#         0.08333333, 0.07692308, 0.07142857, 0.06666667, 0.0625    ],
# ...

# %%
# Improving image's quality
from IPython import display 
display.set_matplotlib_formats('svg')

import random as r
import matplotlib.pyplot as plt

# Initialize variables
N = 10000
x = np.zeros(N)
y = np.zeros(N)
for i in range(N-1):
    k = r.randint(1,3)
    x[i+1] = 0.5*x[i]+k-1
    y[i+1] = 0.5*y[i]

    if k == 2:
        y[i+1]= y[i]+2
plt.style.use('fivethirtyeight')
plt.plot(x,y,marker='.',color='k',linestyle='none',markersize=0.8)
plt.xticks([])
plt.yticks([])
plt.grid('False')
plt.show()
# Out:
# /tmp/ipykernel_1603/1321193205.py:3: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   display.set_matplotlib_formats('svg')
